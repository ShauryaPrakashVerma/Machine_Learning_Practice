# %% [markdown]
# <a href="https://colab.research.google.com/github/ShauryaPrakashVerma/Machine_Learning_Practice/blob/main/17_excel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.read_excel('Habit_Tracker.xlsm')
# Out:
# /usr/local/lib/python3.12/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# /usr/local/lib/python3.12/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
#           DAY       DATE    DAILY TASKS Unnamed: 3 Unnamed: 4     Unnamed: 5  \
# 0         NaN        NaT  Drink Water 4     Github     Python  Practice Comm
# 1      Monday 2026-05-28              1          2          1              0
# 2     Tuesday 2026-05-29             -1         -1         -1             -1
# 3   Wednesday 2026-05-30            NaN        NaN        NaN            NaN
# 4    Thursday 2026-05-31            NaN        NaN        NaN            NaN
# ..        ...        ...            ...        ...        ...            ...
# 94  Wednesday 2026-08-29            NaN        NaN        NaN            NaN
# ...

# %%
pd.read_excel('Habit_Tracker.xlsm', index_col="DAY")
# Out:
# /usr/local/lib/python3.12/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# /usr/local/lib/python3.12/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
#                 DATE    DAILY TASKS Unnamed: 3 Unnamed: 4     Unnamed: 5  \
# DAY
# NaN              NaT  Drink Water 4     Github     Python  Practice Comm
# Monday    2026-05-28              1          2          1              0
# Tuesday   2026-05-29             -1         -1         -1             -1
# Wednesday 2026-05-30            NaN        NaN        NaN            NaN
# Thursday  2026-05-31            NaN        NaN        NaN            NaN
# ...              ...            ...        ...        ...            ...
# Wednesday 2026-08-29            NaN        NaN        NaN            NaN
# ...

# %%
# suppose we want another sheet in the excel file
pd.read_excel("Habit_Tracker.xlsm", sheet_name='Sheet1')
# Out:
# /usr/local/lib/python3.12/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# /usr/local/lib/python3.12/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
#           DAY       DATE    DAILY TASKS Unnamed: 3 Unnamed: 4     Unnamed: 5  \
# 0         NaN        NaT  Drink Water 4     Github     Python  Practice Comm
# 1      Monday 2026-05-28              1          2          1              0
# 2     Tuesday 2026-05-29             -1         -1         -1             -1
# 3   Wednesday 2026-05-30            NaN        NaN        NaN            NaN
# 4    Thursday 2026-05-31            NaN        NaN        NaN            NaN
# ..        ...        ...            ...        ...        ...            ...
# 94  Wednesday 2026-08-29            NaN        NaN        NaN            NaN
# ...

# %% [markdown]
# # Reading Text files

# %%
# first recognize how the data in the text file is arranged
# eventually we will use the read_csv functions

# %%
pd.read_csv('questions_answer.txt', sep='\t')
