# %% [markdown]
# <a href="https://colab.research.google.com/github/ShauryaPrakashVerma/Machine_Learning_Practice/blob/main/ML_Beginners_2_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
from sklearn import datasets, linear_model, model_selection

# %%
x, y = datasets.load_diabetes(return_X_y=True)

# %%
x_train, x_test, y_train, y_test = model_selection.train_test_split(x, y, test_size=0.35, random_state=1)

# %%
x_train
# Out:
# array([[ 0.01628068, -0.04464164, -0.02884001, ..., -0.03949338,
#         -0.03074792, -0.04249877],
#        [ 0.01991321,  0.05068012, -0.01267283, ...,  0.03430886,
#          0.00538633,  0.00306441],
#        [ 0.11072668,  0.05068012,  0.00672779, ...,  0.03430886,
#          0.00200444,  0.07762233],
#        ...,
#        [-0.0854304 ,  0.05068012, -0.03099563, ..., -0.03949338,
#         -0.09643495, -0.03421455],
#        [ 0.06713621,  0.05068012, -0.01482845, ...,  0.01290621,
#         -0.00514219,  0.04862759],
#        [-0.00914709, -0.04464164,  0.01103904, ..., -0.03949338,
#          0.01703607, -0.0052198 ]])

# %%
model = linear_model.LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
print(x.shape)
print(x_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (442, 10)
# (287, 10)
# (155, 10)
# (155,)

# %%
plt.scatter(x_test, y_test, color="black")

plt.plot(
    x_test,
    y_pred,
    color="blue",
    linewidth=3
)

plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1801/2465880046.py in <cell line: 0>()
# ----> 1 plt.scatter(x_test, y_test, color="black")
#       2
#       3 plt.plot(
#       4     x_test,
#       5     y_pred,
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#     454
#     455     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, data, **kwargs)
#    3937     **kwargs,
#    3938 ) -> PathCollection:
# ...

# %%
# plt.scatter(x_test, y_test,  color='black')
# plt.plot(x_test, y_pred, color='blue', linewidth=3)
# plt.xlabel('Scaled BMIs')
# plt.ylabel('Disease Progression')
# plt.title('A Graph Plot Showing Diabetes Progression Against BMI')
# plt.show()


plt.scatter(x_test[:, 2], y_test, color="black")
plt.plot(x_test, y_pred, color='blue', linewidth=3)
plt.xlabel("BMI")
plt.ylabel("Disease Progression")
plt.show()
