# %% [markdown]
# <a href="https://colab.research.google.com/github/ShauryaPrakashVerma/Machine_Learning_Practice/blob/main/Cross_Validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Cross Validation**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import cross_val_score, KFold, train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.datasets import load_iris

# %%
dataset = load_iris()
X, y = dataset.data , dataset.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1)

# %%
model = LinearRegression()

# %%
# TYPES OF CROSS VALIDATION

# kf = KFold(
#     n_splits=5,
#     shuffle=True,
#     random_state=42
# )



# StratifiedKFold(...)
# GroupKFold(...)
# TimeSeriesSplit(...)
# RepeatedKFold(...)
# LeaveOneOut(...)

# %%
# scores = cross_val_score(model, X_train, y_train, cv =kf)

# %%
scores = cross_val_score(model, X_train, y_train, cv =5)


# the above statement is equivalent to the below two statements
# kf = KFold(n_splits=5)
# scores = cross_val_score(model, X, y, cv=kf)

# %%
scores
# Out:
# array([0.94099824, 0.90866357, 0.9579735 , 0.95107066, 0.84165208])

# %%
scores.mean()
# Out:
# np.float64(0.9200716100042046)
